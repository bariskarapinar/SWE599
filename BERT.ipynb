# %%
# !pip install Cmake
# !pip3 install keybert
# !pip3 install 'keybert[flair]'
# Out:
# WARNING: The directory '/Users/bariskarapinar/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Collecting Cmake
#   Downloading cmake-3.25.0-py2.py3-none-macosx_10_10_universal2.macosx_10_10_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl (45.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 MB 1.7 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: Cmake
# Successfully installed Cmake-3.25.0
# WARNING: The directory '/Users/bariskarapinar/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Requirement already satisfied: keybert in /opt/homebrew/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: rich>=10.4.0 in /opt/homebrew/lib/python3.10/site-packages (from keybert) (12.6.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /opt/homebrew/lib/python3.10/site-packages (from keybert) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /opt/homebrew/lib/python3.10/site-packages (from keybert) (1.2.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/homebrew/lib/python3.10/site-packages (from keybert) (1.23.5)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/homebrew/lib/python3.10/site-packages (from rich>=10.4.0->keybert) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.10/site-packages (from rich>=10.4.0->keybert) (0.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert) (1.9.3)
# Requirement already satisfied: torch>=1.6.0 in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (1.13.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (0.11.1)
# Requirement already satisfied: sentencepiece in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (0.1.97)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (4.25.1)
# Requirement already satisfied: torchvision in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (0.14.0)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (4.64.1)
# Requirement already satisfied: nltk in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (3.8)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.4.0)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.8.2)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.28.1)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (22.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/homebrew/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.13.2)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.10/site-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/homebrew/lib/python3.10/site-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (9.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.13)
# WARNING: The directory '/Users/bariskarapinar/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Requirement already satisfied: keybert[flair] in /opt/homebrew/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /opt/homebrew/lib/python3.10/site-packages (from keybert[flair]) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /opt/homebrew/lib/python3.10/site-packages (from keybert[flair]) (1.2.0)
# Requirement already satisfied: rich>=10.4.0 in /opt/homebrew/lib/python3.10/site-packages (from keybert[flair]) (12.6.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/homebrew/lib/python3.10/site-packages (from keybert[flair]) (1.23.5)
# Collecting flair>=0.7
#   Downloading flair-0.11.3-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.9/401.9 kB 977.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: transformers>=3.5.1 in /opt/homebrew/lib/python3.10/site-packages (from keybert[flair]) (4.25.1)
# Requirement already satisfied: torch>=1.4.0 in /opt/homebrew/lib/python3.10/site-packages (from keybert[flair]) (1.13.0)
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting bpemb>=0.3.2
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Collecting pptree
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting konoha<5.0.0,>=4.0.0
#   Downloading konoha-4.6.5-py3-none-any.whl (20 kB)
# Collecting deprecated>=1.2.4
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting mpld3==0.3
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 1.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting janome
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 2.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm>=4.26.0 in /opt/homebrew/lib/python3.10/site-packages (from flair>=0.7->keybert[flair]) (4.64.1)
# Requirement already satisfied: sqlitedict>=1.6.0 in /opt/homebrew/lib/python3.10/site-packages (from flair>=0.7->keybert[flair]) (2.1.0)
# Collecting wikipedia-api
#   Downloading Wikipedia-API-0.5.4.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dateutil>=2.6.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Collecting more-itertools
#   Downloading more_itertools-9.0.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: regex in /opt/homebrew/lib/python3.10/site-packages (from flair>=0.7->keybert[flair]) (2022.10.31)
# Collecting hyperopt>=0.2.7
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95.tar.gz (508 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.7/508.7 kB 3.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting segtok>=1.5.7
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting gensim>=3.4.0
#   Downloading gensim-4.2.0-cp310-cp310-macosx_10_9_universal2.whl (24.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 3.4 MB/s eta 0:00:0000:0100:01
# Collecting gdown==4.4.0
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lxml
#   Downloading lxml-4.9.1.tar.gz (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 3.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting matplotlib>=2.2.3
#   Downloading matplotlib-3.6.2-cp310-cp310-macosx_11_0_arm64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 3.4 MB/s eta 0:00:0000:0100:01
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 3.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting conllu>=4.0
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub in /opt/homebrew/lib/python3.10/site-packages (from flair>=0.7->keybert[flair]) (0.11.1)
# Requirement already satisfied: requests[socks] in /opt/homebrew/lib/python3.10/site-packages (from gdown==4.4.0->flair>=0.7->keybert[flair]) (2.28.1)
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.10/site-packages (from gdown==4.4.0->flair>=0.7->keybert[flair]) (3.8.2)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.10/site-packages (from rich>=10.4.0->keybert[flair]) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/homebrew/lib/python3.10/site-packages (from rich>=10.4.0->keybert[flair]) (2.13.0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert[flair]) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert[flair]) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert[flair]) (1.2.0)
# Requirement already satisfied: torchvision in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert[flair]) (0.14.0)
# Requirement already satisfied: nltk in /opt/homebrew/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert[flair]) (3.8)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.10/site-packages (from torch>=1.4.0->keybert[flair]) (4.4.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.10/site-packages (from transformers>=3.5.1->keybert[flair]) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.10/site-packages (from transformers>=3.5.1->keybert[flair]) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/homebrew/lib/python3.10/site-packages (from transformers>=3.5.1->keybert[flair]) (0.13.2)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.14.1-cp310-cp310-macosx_11_0_arm64.whl (35 kB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.1 MB/s eta 0:00:00
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Collecting networkx>=2.2
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 3.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting importlib-metadata<4.0.0,>=3.7.0
#   Downloading importlib_metadata-3.10.1-py3-none-any.whl (14 kB)
# Collecting overrides<4.0.0,>=3.0.0
#   Downloading overrides-3.1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-macosx_11_0_arm64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 3.8 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 3.5 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp310-cp310-macosx_11_0_arm64.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.9/225.9 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=2.2.3->flair>=0.7->keybert[flair]) (9.3.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests[socks]->gdown==4.4.0->flair>=0.7->keybert[flair]) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests[socks]->gdown==4.4.0->flair>=0.7->keybert[flair]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests[socks]->gdown==4.4.0->flair>=0.7->keybert[flair]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests[socks]->gdown==4.4.0->flair>=0.7->keybert[flair]) (1.26.13)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/homebrew/lib/python3.10/site-packages (from ftfy->flair>=0.7->keybert[flair]) (0.2.5)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.10/site-packages (from nltk->sentence-transformers>=0.3.8->keybert[flair]) (8.1.3)
# Collecting zipp>=0.5
#   Downloading zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: gdown, mpld3, sentencepiece, langdetect, lxml, pptree, wikipedia-api, overrides, future
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14759 sha256=73fb15e979736c5eb9ad58cebfda3565ab23d69a72d91790e850ea22f1002b64
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/83/e8/32/df75a5ff57186996bd335fc648e2b45282cb948cfa97274606
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116686 sha256=cbfefeec533767d33a8f354384fd4ced5c942ecacaa5eab3f56c9f9a357f6c5d
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/48/e0/e1/d58204051deeb634d8879ce099131e0adf4dbb954dad6ca0dc
#   Building wheel for sentencepiece (setup.py) ... done
#   Created wheel for sentencepiece: filename=sentencepiece-0.1.95-cp310-cp310-macosx_13_0_arm64.whl size=1089627 sha256=1af669067c006a5fa4c7a72f93bc54e2721d096d178ad8c4ba333d003e608e18
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/cb/8b/07/d61b0033d6a66ed9d5956dd83a9cbfede3c2e5c5f561b03838
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=f8258a0bcb56b1ea9f11ba4a7d81b9f1870d06751abe331a02f941efd33e937f
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/c4/16/af/1889804d8b7c0c041cadee8e29673a938a332acbf2865c70a1
#   Building wheel for lxml (setup.py) ... done
#   Created wheel for lxml: filename=lxml-4.9.1-cp310-cp310-macosx_13_0_arm64.whl size=1481520 sha256=cb768055d0e8cc33336ad0e5a7758b732a02b2da965c4861ed094d348f3e285b
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/72/18/e4/38f0853d6c6d0746db297b9d7daa953b09adb6decff52dd7fb
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4609 sha256=63bdccc2549295fa763db92391ed504fb595542ea6fe742b5bb26ffc702f26f9
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/97/24/c7/eed898e39b268b1990525c2634229c6f6f1be7581dd3d1dc05
#   Building wheel for wikipedia-api (setup.py) ... done
#   Created wheel for wikipedia-api: filename=Wikipedia_API-0.5.4-py3-none-any.whl size=13476 sha256=191d9cadd3d6b9a5a209c286e46601ec569795c2db857491ed9f70703fefd516
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/3a/8a/2a/aa84b90a027f8613996536774b79f3fbf73c242f03de095a02
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-py3-none-any.whl size=10172 sha256=cde9afe04b1368d105651cb42172d9b63f62b9f8f41a0fe99ad7e136e0800ba9
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/a6/10/4d/1da41dc16e0bd815a2a549d81b1e526d6dce63d0feada4e2c4
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=8381e977e92401ff19e24cd6bebe48627e6a96487a38bf25d8fdfacc46482186
#   Stored in directory: /private/var/folders/qs/gt9g62ns60j_4_zkt7rvjlhc0000gn/T/pip-ephem-wheel-cache-a7_930i1/wheels/dc/16/09/eb08b4e34e6b638f113d2018cf0b22de1d8dca22a3a71873f7
# Successfully built gdown mpld3 sentencepiece langdetect lxml pptree wikipedia-api overrides future
# Installing collected packages: sentencepiece, py4j, pptree, overrides, mpld3, janome, zipp, wrapt, tabulate, soupsieve, smart-open, six, segtok, PySocks, pyparsing, networkx, more-itertools, lxml, kiwisolver, future, ftfy, fonttools, cycler, contourpy, conllu, cloudpickle, wikipedia-api, python-dateutil, langdetect, importlib-metadata, hyperopt, gensim, deprecated, beautifulsoup4, matplotlib, konoha, gdown, bpemb, flair
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.97
#     Uninstalling sentencepiece-0.1.97:
#       Successfully uninstalled sentencepiece-0.1.97
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.11.1 bpemb-0.3.4 cloudpickle-2.2.0 conllu-4.5.2 contourpy-1.0.6 cycler-0.11.0 deprecated-1.2.13 flair-0.11.3 fonttools-4.38.0 ftfy-6.1.1 future-0.18.2 gdown-4.4.0 gensim-4.2.0 hyperopt-0.2.7 importlib-metadata-3.10.1 janome-0.4.2 kiwisolver-1.4.4 konoha-4.6.5 langdetect-1.0.9 lxml-4.9.1 matplotlib-3.6.2 more-itertools-9.0.0 mpld3-0.3 networkx-2.8.8 overrides-3.1.0 pptree-3.1 py4j-0.10.9.7 pyparsing-3.0.9 python-dateutil-2.8.2 segtok-1.5.11 sentencepiece-0.1.95 six-1.16.0 smart-open-6.3.0 soupsieve-2.3.2.post1 tabulate-0.9.0 wikipedia-api-0.5.4 wrapt-1.14.1 zipp-3.11.0

# %%
from keybert import KeyBERT
from tqdm.notebook import tqdm

doc = 'The Seventh-day Adventist Church in Tonga, (Tongan: Siasi ʻAhofitu)\
is one of the smaller religious groups in the South Pacific island \
state of Tonga with a reported 3,853 members as of June 30, 2020, \
started by Seventh-day Adventist missionaries from the United States \
who visited in 1891 and settled in 1895. They set up schools but made \
very little progress in conversion, handicapped by dietary rules that \
prohibited popular local foods such as pork and shellfish, and that \
also banned tobacco, alcohol and kava. The church was revitalized \
in 1912 with renewed emphasis on evangelism. In 1922 it resumed its \
strategy of providing education, which resulted in an increase in \
conversions. After keeping a low profile during World War II (1939–45),\
the church grew quickly from 1950 to the 1970s. However, membership \
subsequently declined due to emigration and competition with other \
churches. The SDA of Tonga is part of the South Pacific Division of \
Seventh-day Adventists. It operates several schools in Tonga, \
and provides opportunities for further studies at \
Adventist institutions abroad.'

model = KeyBERT('distilbert-base-nli-mean-tokens')
keywords = model.extract_keywords(doc)

# %%
model.extract_keywords(doc, keyphrase_ngram_range=(1,2), stop_words=None)
# Out:
# [('adventist missionaries', 0.3518),
#  ('day adventists', 0.3441),
#  ('adventist church', 0.3385),
#  ('day adventist', 0.3249),
#  ('june 30', 0.2689)]
